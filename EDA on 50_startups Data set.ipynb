# %% [markdown]
# Import The Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load The Data Set

# %%
data = pd.read_csv("50_Startups.csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# Some information about the dataset

# %%
data.shape
# Out:
# (50, 5)

# %%
data.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %% [markdown]
# Some statistical information about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data["R&D Spend"].unique()
# Out:
# array([165349.2 , 162597.7 , 153441.51, 144372.41, 142107.34, 131876.9 ,
#        134615.46, 130298.13, 120542.52, 123334.88, 101913.08, 100671.96,
#         93863.75,  91992.39, 119943.24, 114523.61,  78013.11,  94657.16,
#         91749.16,  86419.7 ,  76253.86,  78389.47,  73994.56,  67532.53,
#         77044.01,  64664.71,  75328.87,  72107.6 ,  66051.52,  65605.48,
#         61994.48,  61136.38,  63408.86,  55493.95,  46426.07,  46014.02,
#         28663.76,  44069.95,  20229.59,  38558.51,  28754.33,  27892.92,
#         23640.93,  15505.73,  22177.74,   1000.23,   1315.46,      0.  ,
#           542.05])

# %%
sns.histplot(x=data["R&D Spend"],data=data)
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Count'>

# %% [markdown]
# Check the outliers in the R&D Spend column
#
# No outliers

# %%
sns.boxplot(x=data["R&D Spend"],data=data)
# Out:
# <Axes: xlabel='R&D Spend'>

# %%
sns.histplot(x=data["Administration"],data=data)
# Out:
# <Axes: xlabel='Administration', ylabel='Count'>

# %% [markdown]
# Check the otliers in the column Administration
#
# No outliers

# %%
sns.boxplot(x=data["Administration"],data=data)
# Out:
# <Axes: xlabel='Administration'>

# %%
sns.histplot(x=data["Marketing Spend"],data=data)
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Count'>

# %% [markdown]
# Check the outliers in the Marketing Spend column
#
# No Outliers in the Marketing Spend

# %%
sns.boxplot(x=data["Marketing Spend"],data=data)
# Out:
# <Axes: xlabel='Marketing Spend'>

# %%
sns.histplot(x=data["State"],data=data)
# Out:
# <Axes: xlabel='State', ylabel='Count'>

# %%
sns.histplot(x=data["Profit"],data=data)
# Out:
# <Axes: xlabel='Profit', ylabel='Count'>

# %% [markdown]
# Check the outliers in the Profit columns
#
#  outliers in the profit column

# %%
sns.boxplot(x=data["Profit"],data=data)
# Out:
# <Axes: xlabel='Profit'>

# %% [markdown]
# Correlations

# %%
data.corr()
# Out:
# C:\Users\MD SUHAIL MALIK\AppData\Local\Temp\ipykernel_12224\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.heatmap(data.corr(),vmin=-1,annot=True)
# Out:
# C:\Users\MD SUHAIL MALIK\AppData\Local\Temp\ipykernel_12224\3284826886.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),vmin=-1,annot=True)
# <Axes: >
